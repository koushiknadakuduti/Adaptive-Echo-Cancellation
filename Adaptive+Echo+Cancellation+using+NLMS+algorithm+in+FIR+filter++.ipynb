# %%
#Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import math 
import scipy.io as sio
import scipy.io.wavfile as wavefile 
from scipy import signal
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import pandas as pd
#import sounddevice as sd
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
#Load data
music            = pd.read_table('music.txt',delim_whitespace=True,header=None)
corrupted_speech = pd.read_table('corrupted_speech.txt',delim_whitespace=True,header=None)
x= music.values    #Input to filter
x=x.T
#wavefile.write('music.wav',22000,x)
d= corrupted_speech.values                 #Desired output = corrupted speech
d=d.T
N = music.size
sc=StandardScaler()
print(N)
print(d.shape)
x=sc.fit_transform(x)
d=sc.fit_transform(d)
# Out:
# 280223
# (280223, 1)

# %%
step_size = .01837               # declaring step size
M = 50                           # order of the filter
w= np.zeros((M,1))               # Weights
y=np.zeros((N,1))                # output of filter
e = np.zeros((N,1))              # error

# %%
#Plot erle curve from model order 5 to 100 in steps of 5
erle=[]
for M in range(5,101,5):
    w= np.zeros((M,1))
    y=np.zeros((N,1))
    e=np.zeros((N,1))
    for i in range(M,N-2):
        a=x[i-M:i:1]                     #Taking M no. of samples for calculating w %
        y[i]=w.T@a                       # Estimating y using weights%
        e[i]=d[i]-y[i]                   # Computing Error %
        a_optimal = a.T@a
        a_optimal=a/a_optimal
        w=w+2*step_size*a_optimal*e[i]  #Updating Weights %
    erle_e=np.linalg.norm(e,ord=2)
    MSE_e = erle_e**2/N
    erle_d = np.linalg.norm(d,ord=2)
    MSE_d = erle_d**2/N
    erle.append(10*math.log10(MSE_d/MSE_e))
    print(M,'Loop end')
# Out:
# 5 Loop end
# 10 Loop end
# 15 Loop end
# 20 Loop end
# 25 Loop end
# 30 Loop end
# 35 Loop end
# 40 Loop end
# 45 Loop end
# 50 Loop end
# 55 Loop end
# 60 Loop end
# 65 Loop end
# 70 Loop end
# 75 Loop end
# 80 Loop end
# 85 Loop end
# 90 Loop end
# 95 Loop end
# 100 Loop end

# %%
#ERLE_Plot
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(range(5,101,5),erle)
ax.set_xlabel('Model Order')
ax.set_ylabel('ERLE')

# %%
M=50                        #Changing model order
step_size=0.00018           #Changing step size 
w= np.zeros((M,1))          #Changing weights 
y=np.zeros((N,1))           #Changing output
e = np.zeros((N,1))         #Changing error
wmatrix = np.zeros((M,1))   #Weight matrix to track changes in weights
count=0
for i in range(M,N-2):
    count+=1
    a=x[i-M:i:1]            #Taking M no. of samples for calculating w 
    y[i]=w.T@a              #Estimating y using weights
    e[i]=d[i]-y[i]          #Computing Error
    a_optimal = a.T@a
    a_optimal=a/a_optimal
    w=w+2*step_size*a_optimal*e[i]           #Updating Weights 
    if count==100:                                #Not storing all values to speed up computations
        wmatrix = np.column_stack((wmatrix,w))
        count=0
erle_e=np.linalg.norm(e,ord=2)
MSE_e = erle_e**2
erle_d=np.linalg.norm(d,ord=2)
MSE_d = erle_d**2
print(10*math.log10(MSE_d/MSE_e))
print(wmatrix.shape)
# Out:
# 5.288838505816983
# (50, 2802)

# %%
#Weight curves
plt.gca()
for k in range(0,M):
    plt.plot(range(0,2802),wmatrix[k,:])
plt.xlabel('Sample')
plt.ylabel('Weight Curves')
plt.show()

# %%
#Learning curve
J = np.zeros((30,1))
for samp in range(0,30):
    cw = wmatrix[:,samp]
    error_sum = 0
    for i in range(M,N-1):
        a = np.array(x[i-M:i:1])
        y[i] = cw.T@a
        e[i] = d[i] - y[i]
        error_sum = error_sum + (e[i]**2)
    J[samp] = error_sum/(2*(N-M))

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(range(0,len(J)),J)
ax.set_xlabel('Samples')
ax.set_ylabel('E')

# %%
#Create Audio file in .wav format

wavefile.write('recovered_speech.wav',22000,e)
